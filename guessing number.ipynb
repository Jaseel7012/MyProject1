# %%
#Number guessing python program
import random
user=print("Enter number between 1 and 100\nUser Turn")

user_turn=int(input(""))
comp_turn=random.randint(1,100)
   
def compare(user_turn,comp_turn):
    if user_turn==comp_turn:
        print("you won")
    else:
        print("loss")   
compare(user_turn,comp_turn)
# Out:
# Enter number between 1 and 100
# User Turn
# 59
# loss
